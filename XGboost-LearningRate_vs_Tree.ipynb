# %%
# # XGBoost on Otto dataset, Tune learning_rate and n_estimators
# from pandas import read_csv
# from xgboost import XGBClassifier
# from sklearn.model_selection import GridSearchCV
# from sklearn.model_selection import StratifiedKFold
# from sklearn.preprocessing import LabelEncoder
# import matplotlib
# import pandas as pd
# matplotlib.use('Agg')
# from matplotlib import pyplot
# import numpy
# # load data
# train_value = read_csv('train_values.csv')
# train_label = pd.read_csv('train_labels.csv')

# # split data into X and y
# X = train_value.iloc[:,1:].values
# y = train_label.iloc[:,1].values
# # encode string class values as integers
# from sklearn.preprocessing import LabelEncoder, OneHotEncoder
# labelencoder_X_7 = LabelEncoder()
# X[:, 7] = labelencoder_X_7.fit_transform(X[:, 7])
# labelencoder_X_8 = LabelEncoder()
# X[:, 8] = labelencoder_X_8.fit_transform(X[:, 8])
# labelencoder_X_9 = LabelEncoder()
# X[:, 9] = labelencoder_X_8.fit_transform(X[:, 9])
# labelencoder_X_10 = LabelEncoder()
# X[:, 10] = labelencoder_X_10.fit_transform(X[:, 10])
# labelencoder_X_11 = LabelEncoder()
# X[:, 11] = labelencoder_X_7.fit_transform(X[:, 11])
# labelencoder_X_12 = LabelEncoder()
# X[:, 12] = labelencoder_X_7.fit_transform(X[:, 12])
# labelencoder_X_13 = LabelEncoder()
# X[:, 13] = labelencoder_X_7.fit_transform(X[:, 13])
# labelencoder_X_25 = LabelEncoder()
# X[:, 25] = labelencoder_X_7.fit_transform(X[:, 25])
# # grid search
# model = XGBClassifier()
# n_estimators = [500, 1000, 1500, 2000]
# learning_rate = [ 0.01, 0.1]
# param_grid = dict(learning_rate=learning_rate, n_estimators=n_estimators)
# kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=7)
# grid_search = GridSearchCV(model, param_grid, scoring="neg_log_loss", n_jobs=-1, cv=kfold)
# grid_result = grid_search.fit(X, label_encoded_y)
# # summarize results
# print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# means = grid_result.cv_results_['mean_test_score']
# stds = grid_result.cv_results_['std_test_score']
# params = grid_result.cv_results_['params']
# for mean, stdev, param in zip(means, stds, params):
# 	print("%f (%f) with: %r" % (mean, stdev, param))
# # plot results
# scores = numpy.array(means).reshape(len(learning_rate), len(n_estimators))
# for i, value in enumerate(learning_rate):
#     pyplot.plot(n_estimators, scores[i], label='learning_rate: ' + str(value))
# pyplot.legend()
# pyplot.xlabel('n_estimators')
# pyplot.ylabel('Log Loss')
# pyplot.savefig('n_estimators_vs_learning_rate.png')

# %%
#!/usr/bin/env python2
# -*- coding: utf-8 -*-
"""
Created on Mon Apr 16 21:02:07 2018

@author: zhihuanwilson
"""

# XGBoost on Otto dataset, Tune learning_rate and n_estimators
from pandas import read_csv
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder
import matplotlib
import pandas as pd
matplotlib.use('Agg')
from matplotlib import pyplot
import numpy
# load data
train_value = read_csv('train_values.csv')
train_label = pd.read_csv('train_labels.csv')

from sklearn.decomposition import PCA
from sklearn.decomposition import RandomizedPCA

pca = RandomizedPCA()
pca = PCA(n_components=12)
principalComponents = pca.fit_transform(Z)
principalDf = pd.DataFrame(data = principalComponents)

# split data into X and y
X = train_value.iloc[:,1:12].values
y = train_label.iloc[:,1].values
# encode string class values as integers
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
labelencoder_X_7 = LabelEncoder()
X[:, 7] = labelencoder_X_7.fit_transform(X[:, 7])
labelencoder_X_8 = LabelEncoder()
X[:, 8] = labelencoder_X_8.fit_transform(X[:, 8])
labelencoder_X_9 = LabelEncoder()
X[:, 9] = labelencoder_X_8.fit_transform(X[:, 9])
# labelencoder_X_10 = LabelEncoder()
# X[:, 10] = labelencoder_X_10.fit_transform(X[:, 10])
# labelencoder_X_11 = LabelEncoder()
# X[:, 11] = labelencoder_X_7.fit_transform(X[:, 11])


from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state=0)

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

model = XGBClassifier(max_depth=15, learning_rate=0.01, n_estimator=2000)
model.fit(X_train, y_train)

y_pred_XGboost = model.predict(X_test)
from sklearn.metrics import f1_score
F1_XGboost = f1_score(y_test, y_pred_XGboost, average='micro')

# %%
F1_XGboost
# Out:
# 0.64533333333333331

# %%
# #!/usr/bin/env python2
# # -*- coding: utf-8 -*-
# """
# Created on Mon Apr 16 21:02:07 2018

# @author: zhihuanwilson
# """

# # XGBoost on Otto dataset, Tune learning_rate and n_estimators
# from pandas import read_csv
# from xgboost import XGBClassifier
# from sklearn.model_selection import GridSearchCV
# from sklearn.model_selection import StratifiedKFold
# from sklearn.preprocessing import LabelEncoder
# import matplotlib
# import pandas as pd
# matplotlib.use('Agg')
# from matplotlib import pyplot
# import numpy
# # load data
# train_value = read_csv('train_values.csv')
# train_label = pd.read_csv('train_labels.csv')

# # split data into X and y
# X = train_value.iloc[:,1:].values
# y = train_label.iloc[:,1].values
# # encode string class values as integers
# from sklearn.preprocessing import LabelEncoder, OneHotEncoder
# labelencoder_X_7 = LabelEncoder()
# X[:, 7] = labelencoder_X_7.fit_transform(X[:, 7])
# labelencoder_X_8 = LabelEncoder()
# X[:, 8] = labelencoder_X_8.fit_transform(X[:, 8])
# labelencoder_X_9 = LabelEncoder()
# X[:, 9] = labelencoder_X_8.fit_transform(X[:, 9])
# labelencoder_X_10 = LabelEncoder()
# X[:, 10] = labelencoder_X_10.fit_transform(X[:, 10])
# labelencoder_X_11 = LabelEncoder()
# X[:, 11] = labelencoder_X_7.fit_transform(X[:, 11])
# labelencoder_X_12 = LabelEncoder()
# X[:, 12] = labelencoder_X_7.fit_transform(X[:, 12])
# labelencoder_X_13 = LabelEncoder()
# X[:, 13] = labelencoder_X_7.fit_transform(X[:, 13])
# labelencoder_X_25 = LabelEncoder()
# X[:, 25] = labelencoder_X_7.fit_transform(X[:, 25])

# from sklearn.decomposition import PCA
# from sklearn.decomposition import RandomizedPCA

# pca = RandomizedPCA()
# pca = PCA(n_components=10)
# principalComponents = pca.fit_transform(train_value)
# principalDf = pd.DataFrame(data = principalComponents)


# from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(principalDf, y, test_size = 0.30, random_state=0)

# from sklearn.preprocessing import StandardScaler
# sc = StandardScaler()
# X_train = sc.fit_transform(X_train)
# X_test = sc.transform(X_test)

# model = XGBClassifier(max_depth=15, learning_rate=0.01, n_estimator=2000)
# model.fit(X_train, y_train)

# y_pred_XGboost = model.predict(X_test)
# from sklearn.metrics import f1_score
# F1_XGboost = f1_score(y_test, y_pred_XGboost, average='micro')

# %%
F1_XGboost
# Out:
# 0.59799999999999998

# %%
X = train_value[['geo_level_1_id', 'geo_level_2_id', 'geo_level_3_id',
                 'count_floors_pre_eq', 'age', 'area', 'height',
                 'foundation_type']]
y = train_label.iloc[:,1].values

# %%
X.head()
# Out:
#    geo_level_1_id  geo_level_2_id  geo_level_3_id  count_floors_pre_eq  age  \
# 0               8             501            3237                    2   25
# 1               7             288            1819                    3   15
# 2              14              36             838                    1   20
# 3               8              81             805                    2    5
# 4              23             380            4266                    3    0
#
#    area  height foundation_type
# 0    33       4            337f
# 1    28       5            337f
# 2    37       2            337f
# 3    18       3            337f
# 4    39       6            337f

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame
